# %%
# coding: utf-8
import sys, time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# %%
df = pd.read_csv('./output/res/0109_2000_300_600_30_rb.csv', index_col=0)

# %%
df.head()
# Out:
#              MeanServiceRate  SharedRate  DetourRatio       Delay        Wait  \
# Reblance            0.693062    0.947483     0.096173  195.124382  131.730362
# No-Reblance         0.641048    0.945650     0.102500  201.929130  130.513238
#
#                  MeanDist   MeanRbDist            GMV
# Reblance     21459.469102  2851.221626  201602.820016
# No-Reblance  19886.374928     0.000000  197880.152203

# %%
# 
x = df.index.values
# xticks = ['0103', '0104', '0105', '0106', '0107', '0108', '0109']
xticks = [str(i) for i in x]

# %%
# Mean Service Rate
y = df.MeanServiceRate.values
plt.close()
fig, ax = plt.subplots(figsize=(8,6), dpi=100, facecolor="white")
ax.plot(x, y, '-o', c='r', lw=2, mew=2, ms=10, mfc='red', mec='r')
ax.tick_params(direction='in', pad=5)
ax.set_ylim([0.3, 1.0])
ax.set_xlabel("Number of Vehicles", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.set_ylabel("Mean Service Rate", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.grid(linestyle=':', color='black')
ax.set_xticks(x)
ax.set_xticklabels(xticks, {'fontsize': 15})
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
# plt.show()
fig.savefig("./output/img/vehicle/MSR.png", bbox_inches='tight')

# %%
# Mean Service Rate
y = df.SharedRate.values
plt.close()
fig, ax = plt.subplots(figsize=(8,6), dpi=100, facecolor="white")
# xticks = [str(i) for i in x]
ax.plot(x, y, '-o', c='r', lw=2, mew=2, ms=10, mfc='red', mec='r')
ax.tick_params(direction='in', pad=5)
ax.set_ylim([0.90, 0.98])
ax.set_xlabel("Number of Vehicles", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.set_ylabel("Mean Shared Rate", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.grid(linestyle=':', color='black')
ax.set_xticks(x)
ax.set_xticklabels(xticks, {'fontsize': 15})
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
# plt.show()
fig.savefig("./output/img/vehicle/SR.png", bbox_inches='tight')

# %%
# Mean Detour Ratio
y = df.DetourRatio.values
plt.close()
fig, ax = plt.subplots(figsize=(8,6), dpi=100, facecolor="white")
# xticks = [str(i) for i in x]
ax.plot(x, y, '-o', c='r', lw=2, mew=2, ms=10, mfc='red', mec='r')
ax.tick_params(direction='in', pad=5)
ax.set_ylim([0.08, 0.15])
ax.set_xlabel("Number of Vehicles", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.set_ylabel("Mean Detour Ratio", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.grid(linestyle=':', color='black')
ax.set_xticks(x)
ax.set_xticklabels(xticks, {'fontsize': 15})
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
# plt.show()
fig.savefig("./output/img/vehicle/MDR.png", bbox_inches='tight')

# %%
# Mean Waiting Delay
y = df.Wait.values
plt.close()
fig, ax = plt.subplots(figsize=(8,6), dpi=100, facecolor="white")
# xticks = [str(i) for i in x]
ax.plot(x, y, '-o', c='r', lw=2, mew=2, ms=10, mfc='red', mec='r')
ax.tick_params(direction='in', pad=5)
ax.set_ylim([100, 150])
ax.set_xlabel("Number of Vehicles", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.set_ylabel("Mean Waiting Delay (s)", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.grid(linestyle=':', color='black')
ax.set_xticks(x)
ax.set_xticklabels(xticks, {'fontsize': 15})
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
# plt.show()
fig.savefig("./output/img/vehicle/MWD.png", bbox_inches='tight')

# %%
# Mean Travel Delay
y = df.Delay.values
plt.close()
fig, ax = plt.subplots(figsize=(8,6), dpi=100, facecolor="white")
# xticks = [str(i) for i in x]
ax.plot(x, y, '-o', c='r', lw=2, mew=2, ms=10, mfc='red', mec='r')
ax.tick_params(direction='in', pad=5)
ax.set_ylim([140, 260])
ax.set_xlabel("Number of Vehicles", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.set_ylabel("Mean Travel Delay (s)", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.grid(linestyle=':', color='black')
ax.set_xticks(x)
ax.set_xticklabels(xticks, {'fontsize': 15})
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
# plt.show()
fig.savefig("./output/img/vehicle/MTD.png", bbox_inches='tight')

# %%
# Mean Travel Distance
y = df.MeanDist.values
plt.close()
fig, ax = plt.subplots(figsize=(8,6), dpi=100, facecolor="white")
# xticks = [str(i) for i in x]
ax.plot(x, y, '-o', c='r', lw=2, mew=2, ms=10, mfc='red', mec='r')
ax.tick_params(direction='in', pad=5)
ax.set_ylim([2500, 27500])
ax.set_xlabel("Number of Vehicles", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.set_ylabel("Mean Travel Distance (m)", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.grid(linestyle=':', color='black')
ax.set_xticks(x)
ax.set_xticklabels(xticks, {'fontsize': 15})
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
# plt.show()
fig.savefig("./output/img/vehicle/MD.png", bbox_inches='tight')
