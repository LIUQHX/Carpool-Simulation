# %%
# coding: utf-8
import sys, time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# %%
df = pd.read_csv('./output/res/dates_2000_300_600_30.csv', index_col=0)

# %%
df.head()
# Out:
#           MeanServiceRate  SharedRate  DetourRatio       Delay        Wait  \
# 20160103         0.800953    0.937234     0.095794  184.011212  126.112757
# 20160104         0.988246    0.726073     0.070945  152.739416   85.779027
# 20160105         0.994248    0.760125     0.089411  165.698415   94.146760
# 20160106         0.995050    0.788149     0.084291  160.532910   94.250862
# 20160107         0.996209    0.834982     0.105340  187.632733  114.237099
#
#               MeanDist   MeanRbDist            GMV
# 20160103  20353.141660  3121.687161  185154.119237
# 20160104   9116.161407   308.774262   67598.179334
# 20160105  10105.336027   226.732118   76627.952569
# 20160106  10698.069734   174.951498   80546.758095
# 20160107  12017.372216    91.141247   90681.116663

# %%
# 
x = df.index.values
xticks = ['0103', '0104', '0105', '0106', '0107', '0108', '0109']

# %%
# Mean Service Rate
y = df.MeanServiceRate.values
plt.close()
fig, ax = plt.subplots(figsize=(8,6), dpi=100, facecolor="white")
ax.plot(x, y, '-o', c='r', lw=2, mew=2, ms=10, mfc='red', mec='r')
ax.tick_params(direction='in', pad=5)
# ax.set_ylim([0.66, 0.72])
ax.set_xlabel("Date", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.set_ylabel("Mean Service Rate", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.grid(linestyle=':', color='black')
ax.set_xticks(x)
ax.set_xticklabels(xticks, {'fontsize': 15})
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
# plt.show()
fig.savefig("./output/img/dates/MSR.png", bbox_inches='tight')

# %%
# Mean Service Rate
y = df.SharedRate.values
plt.close()
fig, ax = plt.subplots(figsize=(8,6), dpi=100, facecolor="white")
# xticks = [str(i) for i in x]
ax.plot(x, y, '-o', c='r', lw=2, mew=2, ms=10, mfc='red', mec='r')
ax.tick_params(direction='in', pad=5)
ax.set_ylim([0.7, 1])
ax.set_xlabel("Date", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.set_ylabel("Mean Shared Rate", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.grid(linestyle=':', color='black')
ax.set_xticks(x)
ax.set_xticklabels(xticks, {'fontsize': 15})
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
# plt.show()
fig.savefig("./output/img/dates/SR.png", bbox_inches='tight')

# %%
# Mean Detour Ratio
y = df.DetourRatio.values
plt.close()
fig, ax = plt.subplots(figsize=(8,6), dpi=100, facecolor="white")
# xticks = [str(i) for i in x]
ax.plot(x, y, '-o', c='r', lw=2, mew=2, ms=10, mfc='red', mec='r')
ax.tick_params(direction='in', pad=5)
ax.set_ylim([0.065, 0.11])
ax.set_xlabel("Date", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.set_ylabel("Mean Detour Ratio", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.grid(linestyle=':', color='black')
ax.set_xticks(x)
ax.set_xticklabels(xticks, {'fontsize': 15})
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
# plt.show()
fig.savefig("./output/img/dates/MDR.png", bbox_inches='tight')

# %%
# Mean Waiting Delay
y = df.Wait.values
plt.close()
fig, ax = plt.subplots(figsize=(8,6), dpi=100, facecolor="white")
# xticks = [str(i) for i in x]
ax.plot(x, y, '-o', c='r', lw=2, mew=2, ms=10, mfc='red', mec='r')
ax.tick_params(direction='in', pad=5)
ax.set_ylim([80, 140])
ax.set_xlabel("Date", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.set_ylabel("Mean Waiting Delay (s)", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.grid(linestyle=':', color='black')
ax.set_xticks(x)
ax.set_xticklabels(xticks, {'fontsize': 15})
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
# plt.show()
fig.savefig("./output/img/dates/MWD.png", bbox_inches='tight')

# %%
# Mean Travel Delay
y = df.Delay.values
plt.close()
fig, ax = plt.subplots(figsize=(8,6), dpi=100, facecolor="white")
# xticks = [str(i) for i in x]
ax.plot(x, y, '-o', c='r', lw=2, mew=2, ms=10, mfc='red', mec='r')
ax.tick_params(direction='in', pad=5)
ax.set_ylim([150, 200])
ax.set_xlabel("Date", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.set_ylabel("Mean Travel Delay (s)", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.grid(linestyle=':', color='black')
ax.set_xticks(x)
ax.set_xticklabels(xticks, {'fontsize': 15})
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
# plt.show()
fig.savefig("./output/img/dates/MTD.png", bbox_inches='tight')

# %%
# Mean Travel Distance
y = df.MeanDist.values
plt.close()
fig, ax = plt.subplots(figsize=(8,6), dpi=100, facecolor="white")
# xticks = [str(i) for i in x]
ax.plot(x, y, '-o', c='r', lw=2, mew=2, ms=10, mfc='red', mec='r')
ax.tick_params(direction='in', pad=5)
ax.set_ylim([8000, 22000])
ax.set_xlabel("Date", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.set_ylabel("Mean Travel Distance (m)", {'fontsize': 22, 'fontweight': 'bold'}, labelpad=10)
ax.grid(linestyle=':', color='black')
ax.set_xticks(x)
ax.set_xticklabels(xticks, {'fontsize': 15})
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
# plt.show()
fig.savefig("./output/img/dates/MD.png", bbox_inches='tight')
